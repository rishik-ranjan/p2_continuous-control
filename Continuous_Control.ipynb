# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, we will work on the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

import random
import torch
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

plt.ion()

from ddpg_agent import Agent

agent = Agent(state_size=33, action_size=4, random_seed=0)

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='Reacher.app')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]

print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 1
# Size of each action: 4
# There are 1 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726671e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
# env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
# states = env_info.vector_observations                  # get the current state (for each agent)
# scores = np.zeros(num_agents)                          # initialize the score (for each agent)
# while True:
#     actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
#     actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
#     env_info = env.step(actions)[brain_name]           # send all actions to tne environment
#     next_states = env_info.vector_observations         # get next state (for each agent)
#     rewards = env_info.rewards                         # get reward (for each agent)
#     dones = env_info.local_done                        # see if episode finished
#     scores += env_info.rewards                         # update the score (for each agent)
#     states = next_states                               # roll over states to next time step
#     if np.any(dones):                                  # exit loop if episode finished
#         break
# print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
# env.close()

# %% [markdown]
# ### 4. Training the Agent with DDPG
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
def ddpg(n_episodes=400, max_t=1000):
#     print('Please see this')
    scores_deque = deque(maxlen=100)
    scores_list = []
    max_score = -np.Inf
    for i_episode in range(1, n_episodes+1):
#         print('And this')
        env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
        states = env_info.vector_observations                  # get the current state (for each agent)
        scores = np.zeros(num_agents)                          # initialize the score (for each agent)
        agent.reset()
#         print('This too')
        for t in range(max_t):
#             print('You are in the loop now')
            actions = agent.act(states)
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                         # get reward (for each agent)
            dones = env_info.local_done                        # see if episode finished
#             print(states,actions,rewards,next_states,dones)
            agent.step(states, actions, rewards, next_states, dones)
            states = next_states
            scores += rewards
            
            if np.any(dones):
                break
#             action = agent.act(state)
#             env_info = env.step(action)[brain_name]
#             next_state = env_info.vector_observations   # get the next state
#             reward = env_info.rewards                   # get the reward
#             done = env_info.local_done  
#             print(state,action,reward,next_state,done)
#             agent.step(state, action, reward, next_state, done)
#             state = next_state
#             if t == 1:
#                 print(reward)
#             score += reward[0]
#             if done[0]:
#                 break
                
        score = np.mean(scores)
        scores_deque.append(score)
        scores_list.append(score)
        
        print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        if i_episode % 100 == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))   
        if np.mean(scores_deque) >= 31:
            print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            break
        
    return scores_list

# %%
scores = ddpg()

# %%
def ddpg(n_episodes=1000, max_t=1000, print_every=100):
    scores = []
    scores_deque = deque(maxlen=print_every)
    for i_episode in range(1, n_episodes+1):
#         print(i_episode)
        env_info = env.reset(train_mode=True)[brain_name]
        state = env_info.vector_observations
        score = 0
        agent.reset()
#         print(i_episode)
        for t in range(max_t):
            action = agent.act(state)
            env_info = env.step(action)[brain_name]
            next_state = env_info.vector_observations   # get the next state
            reward = env_info.rewards                   # get the reward
            done = env_info.local_done 
#             print(state,action,reward,next_state,done)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            
            score += reward[0]
#             if reward[0]>0:
#                 print(reward)
            if done[0]:
                break
#         print(i_episode)    
        scores_deque.append(score)
        scores.append(score)

        print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))

        if i_episode % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
        if np.mean(scores_deque)>=30.0:
            print('Environment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
            break
    
    
    torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
    torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
    return scores

allscores = ddpg()
# Out:
# Episode 1	Average Score: 0.04
# Episode 2	Average Score: 0.79
# Episode 3	Average Score: 1.03
# Episode 4	Average Score: 0.82
# Episode 5	Average Score: 0.72
# Episode 6	Average Score: 0.66
# Episode 7	Average Score: 0.62
# Episode 8	Average Score: 0.54
# Episode 9	Average Score: 0.58
# Episode 10	Average Score: 0.61
# Episode 11	Average Score: 0.63
# Episode 12	Average Score: 0.58
# Episode 13	Average Score: 0.67
# Episode 14	Average Score: 0.65
# Episode 15	Average Score: 0.71
# Episode 16	Average Score: 0.71
# Episode 17	Average Score: 0.72
# Episode 18	Average Score: 0.71
# Episode 19	Average Score: 0.70
# Episode 20	Average Score: 0.71
# Episode 21	Average Score: 0.72
# Episode 22	Average Score: 0.74
# Episode 23	Average Score: 0.76
# Episode 24	Average Score: 0.79
# Episode 25	Average Score: 0.78
# Episode 26	Average Score: 0.81
# Episode 27	Average Score: 0.85
# Episode 28	Average Score: 0.90
# Episode 29	Average Score: 0.93
# Episode 30	Average Score: 0.95
# Episode 31	Average Score: 0.95
# Episode 32	Average Score: 0.94
# Episode 33	Average Score: 0.91
# Episode 34	Average Score: 0.92
# Episode 35	Average Score: 0.97
# Episode 36	Average Score: 0.97
# Episode 37	Average Score: 0.99
# Episode 38	Average Score: 0.98
# Episode 39	Average Score: 0.99
# Episode 40	Average Score: 1.01
# Episode 41	Average Score: 1.06
# Episode 42	Average Score: 1.06
# Episode 43	Average Score: 1.09
# Episode 44	Average Score: 1.15
# Episode 45	Average Score: 1.17
# Episode 46	Average Score: 1.20
# Episode 47	Average Score: 1.26
# Episode 48	Average Score: 1.26
# Episode 49	Average Score: 1.26
# Episode 50	Average Score: 1.33
# Episode 51	Average Score: 1.37
# Episode 52	Average Score: 1.39
# Episode 53	Average Score: 1.41
# Episode 54	Average Score: 1.45
# Episode 55	Average Score: 1.48
# Episode 56	Average Score: 1.51
# Episode 57	Average Score: 1.51
# Episode 58	Average Score: 1.53
# Episode 59	Average Score: 1.53
# Episode 60	Average Score: 1.51
# Episode 61	Average Score: 1.54
# Episode 62	Average Score: 1.55
# Episode 63	Average Score: 1.57
# Episode 64	Average Score: 1.57
# Episode 65	Average Score: 1.60
# Episode 66	Average Score: 1.60
# Episode 67	Average Score: 1.60
# Episode 68	Average Score: 1.61
# Episode 69	Average Score: 1.75
# Episode 70	Average Score: 1.77
# Episode 71	Average Score: 1.77
# Episode 72	Average Score: 1.80
# Episode 73	Average Score: 1.81
# Episode 74	Average Score: 1.81
# Episode 75	Average Score: 1.81
# Episode 76	Average Score: 1.91
# Episode 77	Average Score: 1.92
# Episode 78	Average Score: 1.93
# Episode 79	Average Score: 1.93
# Episode 80	Average Score: 1.96
# Episode 81	Average Score: 1.97
# Episode 82	Average Score: 1.95
# Episode 83	Average Score: 2.01
# Episode 84	Average Score: 2.02
# Episode 85	Average Score: 2.03
# Episode 86	Average Score: 2.05
# Episode 87	Average Score: 2.05
# Episode 88	Average Score: 2.05
# Episode 89	Average Score: 2.05
# Episode 90	Average Score: 2.14
# Episode 91	Average Score: 2.18
# Episode 92	Average Score: 2.17
# Episode 93	Average Score: 2.19
# Episode 94	Average Score: 2.21
# Episode 95	Average Score: 2.25
# Episode 96	Average Score: 2.25
# Episode 97	Average Score: 2.27
# Episode 98	Average Score: 2.30
# Episode 99	Average Score: 2.29
# Episode 100	Average Score: 2.33
# Episode 100	Average Score: 2.33
# Episode 101	Average Score: 2.40
# Episode 102	Average Score: 2.41
# Episode 103	Average Score: 2.43
# Episode 104	Average Score: 2.47
# Episode 105	Average Score: 2.53
# Episode 106	Average Score: 2.59
# Episode 107	Average Score: 2.59
# Episode 108	Average Score: 2.61
# Episode 109	Average Score: 2.68
# Episode 110	Average Score: 2.72
# Episode 111	Average Score: 2.78
# Episode 112	Average Score: 2.83
# Episode 113	Average Score: 2.86
# Episode 114	Average Score: 2.93
# Episode 115	Average Score: 2.92
# Episode 116	Average Score: 2.99
# Episode 117	Average Score: 3.02
# Episode 118	Average Score: 3.05
# Episode 119	Average Score: 3.09
# Episode 120	Average Score: 3.15
# Episode 121	Average Score: 3.23
# Episode 122	Average Score: 3.25
# Episode 123	Average Score: 3.35
# Episode 124	Average Score: 3.38
# Episode 125	Average Score: 3.42
# Episode 126	Average Score: 3.49
# Episode 127	Average Score: 3.50
# Episode 128	Average Score: 3.62
# Episode 129	Average Score: 3.65
# Episode 130	Average Score: 3.70
# Episode 131	Average Score: 3.73
# Episode 132	Average Score: 3.88
# Episode 133	Average Score: 3.95
# Episode 134	Average Score: 4.05
# Episode 135	Average Score: 4.20
# Episode 136	Average Score: 4.28
# Episode 137	Average Score: 4.37
# Episode 138	Average Score: 4.43
# Episode 139	Average Score: 4.55
# Episode 140	Average Score: 4.62
# Episode 141	Average Score: 4.70
# Episode 142	Average Score: 4.83
# Episode 143	Average Score: 4.92
# Episode 144	Average Score: 4.94
# Episode 145	Average Score: 5.10
# Episode 146	Average Score: 5.23
# Episode 147	Average Score: 5.27
# Episode 148	Average Score: 5.43
# Episode 149	Average Score: 5.64
# Episode 150	Average Score: 5.68
# Episode 151	Average Score: 5.80
# Episode 152	Average Score: 5.95
# Episode 153	Average Score: 6.01
# Episode 154	Average Score: 6.12
# Episode 155	Average Score: 6.13
# Episode 156	Average Score: 6.16
# Episode 157	Average Score: 6.29
# Episode 158	Average Score: 6.59
# Episode 159	Average Score: 6.67
# Episode 160	Average Score: 6.83
# Episode 161	Average Score: 6.98
# Episode 162	Average Score: 7.02
# Episode 163	Average Score: 7.21
# Episode 164	Average Score: 7.47
# Episode 165	Average Score: 7.66
# Episode 166	Average Score: 7.90
# Episode 167	Average Score: 8.06
# Episode 168	Average Score: 8.33
# Episode 169	Average Score: 8.45
# Episode 170	Average Score: 8.64
# Episode 171	Average Score: 8.84
# Episode 172	Average Score: 8.92
# Episode 173	Average Score: 9.06
# Episode 174	Average Score: 9.35
# Episode 175	Average Score: 9.44
# Episode 176	Average Score: 9.45
# Episode 177	Average Score: 9.46
# Episode 178	Average Score: 9.49
# Episode 179	Average Score: 9.61
# Episode 180	Average Score: 9.77
# Episode 181	Average Score: 10.04
# Episode 182	Average Score: 10.15
# Episode 183	Average Score: 10.37
# Episode 184	Average Score: 10.60
# Episode 185	Average Score: 10.78
# Episode 186	Average Score: 10.98
# Episode 187	Average Score: 11.21
# Episode 188	Average Score: 11.45
# Episode 189	Average Score: 11.69
# Episode 190	Average Score: 11.91
# Episode 191	Average Score: 12.13
# Episode 192	Average Score: 12.39
# Episode 193	Average Score: 12.67
# Episode 194	Average Score: 12.94
# Episode 195	Average Score: 13.20
# Episode 196	Average Score: 13.38
# Episode 197	Average Score: 13.47
# Episode 198	Average Score: 13.58
# Episode 199	Average Score: 13.86
# Episode 200	Average Score: 14.02
# Episode 200	Average Score: 14.02
# Episode 201	Average Score: 14.22
# Episode 202	Average Score: 14.39
# Episode 203	Average Score: 14.71
# Episode 204	Average Score: 15.00
# Episode 205	Average Score: 15.25
# Episode 206	Average Score: 15.43
# Episode 207	Average Score: 15.69
# Episode 208	Average Score: 15.97
# Episode 209	Average Score: 16.15
# Episode 210	Average Score: 16.44
# Episode 211	Average Score: 16.71
# Episode 212	Average Score: 16.85
# Episode 213	Average Score: 17.07
# Episode 214	Average Score: 17.20

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(allscores)+1), allscores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(allscores)+1), allscores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.savefig('14scoreintmax400.png')

# %%
# state = env_info.vector_observations[0]
# print(type(state))

# env_info = env.reset(train_mode=True)[brain_name]
# state = env_info.vector_observations[0]
# agent.act(state)

# torch.from_numpy(state)

# type(state)

# print("FACE " + " YOURDEMON")

# %%
torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')

# %%
plt(allscores)

# %% [markdown]
# ### 5. Watch a Smart Agent!

# %%
# agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
# agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))

# state = env.reset()
# for t in range(200):
#     action = agent.act(state, add_noise=False)
#     env.render()
#     state, reward, done, _ = env.step(action)
#     if done:
#         break

# env.close()
